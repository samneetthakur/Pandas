# %%
import pandas as pd
inpFilePath ='/Users/sam/git/Pandas_Data/Input/Data_2019/'
df = pd.read_csv(inpFilePath+'survey_results_public.csv')
schema_df = pd.read_csv(inpFilePath+'survey_results_schema.csv')
pd.set_option('display.max_columns', 85) #to display all columns in the dataframe
pd.set_option('display.max_rows', 85)   #to see all rows in the dataframe of schema
pd.set_option('max_colwidth', 100) #to see the 1000 chars column width of the dataframe of schema

# %%
df
# Out:
#        Respondent  \
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
# ...           ...
# 88878       88377
# 88879       88601
# 88880       88802
# 88881       88816
# 88882       88863
#
#                                                                           MainBranch  \
# 0                                             I am a student who is learning to code
# 1                                             I am a student who is learning to code
# 2      I am not primarily a developer, but I write code sometimes as part of my work
# 3                                                     I am a developer by profession
# 4                                                     I am a developer by profession
# ...                                                                              ...
# 88878                                                                            NaN
# ...

# %%
people = {
    "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", "Doe", "Smith"],
    "email": ["Corey.Schafer@gmail.com", "Jane.Doe@gmail.com", "John.Smith@gmail.com"]
}

# %%
df1 = pd.DataFrame(people)

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@gmail.com
# 1   Jane      Doe       Jane.Doe@gmail.com
# 2   John    Smith     John.Smith@gmail.com

# %%
df1.set_index('email') #email column is now index of the dataframe
#i.e. loc will now use email column to access the data instead of the default index (0,1,2)
#this function call will not change the original dataframe df1, 
# it will return a new dataframe with email as index. 
# To change the original dataframe we can use inplace=True
#df1.set_index('email', inplace=True)
# Out:
#                          first     last
# email
# Corey.Schafer@gmail.com  Corey  Schafer
# Jane.Doe@gmail.com        Jane      Doe
# John.Smith@gmail.com      John    Smith

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@gmail.com
# 1   Jane      Doe       Jane.Doe@gmail.com
# 2   John    Smith     John.Smith@gmail.com

# %%
df1.set_index('email', inplace=True)
#This might be useful when email address as index 
# given nice unique indentifier  to search as row
#now email has become label for loc method to search for row

# %%
df1
# Out:
#                          first     last
# email
# Corey.Schafer@gmail.com  Corey  Schafer
# Jane.Doe@gmail.com        Jane      Doe
# John.Smith@gmail.com      John    Smith

# %%
df1.index
# Out:
# Index(['Corey.Schafer@gmail.com', 'Jane.Doe@gmail.com',
#        'John.Smith@gmail.com'],
#       dtype='object', name='email')

# %%
df1.loc['Corey.Schafer@gmail.com']
# Out:
# first      Corey
# last     Schafer
# Name: Corey.Schafer@gmail.com, dtype: object

# %%
df1.loc['Corey.Schafer@gmail.com','last']
# Out:
# 'Schafer'

# %%
#df1.loc[0] #this will give error as email is index and not number
'''
---------------------------------------------------------------------------
KeyError                                  Traceback (most recent call last)
~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
   2894             try:
-> 2895                 return self._engine.get_loc(casted_key)
   2896             except KeyError as err:

pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()

pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()

pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()

pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()

KeyError: 0

The above exception was the direct cause of the following exception:

KeyError                                  Traceback (most recent call last)
<ipython-input-17-b8b9d5afcc6b> in <module>
----> 1 df1.loc[0] #this will give error as email is index and not number

~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
    877 
...
-> 2897                 raise KeyError(key) from err
   2898 
   2899         if tolerance is not No

'''
# Out:
# '\n---------------------------------------------------------------------------\nKeyError                                  Traceback (most recent call last)\n~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)\n   2894             try:\n-> 2895                 return self._engine.get_loc(casted_key)\n   2896             except KeyError as err:\n\npandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()\n\npandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()\n\npandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()\n\npandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()\n\nKeyError: 0\n\nThe above exception was the direct cause of the following exception:\n\nKeyError                                  Traceback (most recent call last)\n<ipython-input-17-b8b9d5afcc6b> in <module>\n----> 1 df1.loc[0] #this will give error as 
# ...

# %%
df1.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: Corey.Schafer@gmail.com, dtype: object

# %%
df1.reset_index(inplace=True) #to reset the index to default number

# %%
df1 #email is now back as column and index is default number
# Out:
#                      email  first     last
# 0  Corey.Schafer@gmail.com  Corey  Schafer
# 1       Jane.Doe@gmail.com   Jane      Doe
# 2     John.Smith@gmail.com   John    Smith

# %%
df2 = pd.read_csv(inpFilePath+'survey_results_public.csv',index_col='Respondent') 
#this will set Respondent column as index of the dataframe
df2.head(5)
# Out:
#                                                                                MainBranch  \
# Respondent
# 1                                                  I am a student who is learning to code
# 2                                                  I am a student who is learning to code
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 4                                                          I am a developer by profession
# 5                                                          I am a developer by profession
#
#            Hobbyist                 OpenSourcer  \
# Respondent
# 1               Yes                       Never
# 2                No     Less than once per year
# 3               Yes                       Never
# 4                No                       Never
# 5               Yes  Once a month or more often
#
#                                                                                  OpenSource  \
# Respondent
# ...

# %%
df2.loc[1,'MainBranch':'Country'] 
#to access row with index label 1 which is Respondent number 1
#this is equivalent to df.iloc[0] as index starts from 0 in iloc and from 1 in loc for this dataframe
# Out:
# MainBranch                              I am a student who is learning to code
# Hobbyist                                                                   Yes
# OpenSourcer                                                              Never
# OpenSource     The quality of OSS and closed source software is about the same
# Employment                              Not employed, and not looking for work
# Country                                                         United Kingdom
# Name: 1, dtype: object

# %%
 
#df2.iloc[0,'MainBranch':'Country']
#this will give error as iloc only accepts integer position and not column labels

df2.iloc[0,0:6]
# Out:
# MainBranch                              I am a student who is learning to code
# Hobbyist                                                                   Yes
# OpenSourcer                                                              Never
# OpenSource     The quality of OSS and closed source software is about the same
# Employment                              Not employed, and not looking for work
# Country                                                         United Kingdom
# Name: 1, dtype: object

# %%
schema_df2 = pd.read_csv(inpFilePath+'survey_results_schema.csv',index_col='Column')

# %%
schema_df2
# Out:
#                                                                                                                QuestionText
# Column
# Respondent                                           Randomized respondent ID number (not in order of survey response time)
# MainBranch              Which of the following options best describes you today? Here, by "developer" we mean "someone w...
# Hobbyist                                                                                            Do you code as a hobby?
# OpenSourcer                                                                     How often do you contribute to open source?
# OpenSource                                                 How do you feel about the quality of open source software (OSS)?
# Employment                                            Which of the following best describes your current employment status?
# ...

# %%
schema_df2['QuestionText'] #Will Access the QuestionText column
# Out:
# Column
# Respondent                                             Randomized respondent ID number (not in order of survey response time)
# MainBranch                Which of the following options best describes you today? Here, by "developer" we mean "someone w...
# Hobbyist                                                                                              Do you code as a hobby?
# OpenSourcer                                                                       How often do you contribute to open source?
# OpenSource                                                   How do you feel about the quality of open source software (OSS)?
# Employment                                              Which of the following best describes your current employment status?
# Country                                                                             In which country do you currently reside?
# ...

# %%
#schema_df2['Hobbyist']
#will give error as Hobbyist is not a column

# %%
schema_df2.loc['Hobbyist']
#Will give data present at value QuestionText  for Hobbyist key
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
#schema_df2['MgrIdiot']
#this will give error as MgrIdiot is not a column in the schema dataframe

# %%
schema_df2.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df2.sort_index() 
#will ascending sort the original dataframe based on indexes i.e. rows
# if strings (then alphabetically) if number then increasing value based
# this will update original dataframe 
# if you want to update original dataframe we can use inplace=True
# Out:
#                                                                                                                QuestionText
# Column
# Age                            What is your age (in years)? If you prefer not to answer, you may leave this question blank.
# Age1stCode              At what age did you write your first line of code or program? (E.g., webpage, Hello World, Scrat...
# BetterLife                                       Do you think people born today will have a better life than their parents?
# BlockchainIs                                                           Blockchain / cryptocurrency technology is primarily:
# BlockchainOrg                                How is your organization thinking about or implementing blockchain technology?
# CareerSat                                                         Overall, how satisfied are you with your career thus far?
# ...

# %%
schema_df2.sort_index(ascending=False)
# Out:
#                                                                                                                QuestionText
# Column
# YearsCodePro                                         How many years have you coded professionally (as a part of your work)?
# YearsCode                                                     Including any education, how many years have you been coding?
# WorkWeekHrs                                                                On average, how many hours per week do you work?
# WorkRemote                                                                                  How often do you work remotely?
# WorkPlan                                                                            How structured or planned is your work?
# WorkLoc                                                                                     Where would you prefer to work?
# ...
