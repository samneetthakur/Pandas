# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/sam/git/Pandas'

# %%
ls -tlrh
# Out:
# total 4712
# -rw-r--r--@ 1 sam  staff   227K Mar 31 12:48 Lession3_Pandas.ipynb
# -rw-r--r--@ 1 sam  staff   499K Apr  1 23:03 Lession4_Pandas_Filter.ipynb
# -rw-r--r--@ 1 sam  staff   124K Apr  3 19:20 Lession5_Pandas_Update_Rows_Cols.ipynb
# -rw-r--r--@ 1 sam  staff    30K Apr  3 22:43 Lession6_Pandas_Update_Rows_Col.ipynb
# -rw-r--r--@ 1 sam  staff   237K Apr  4 13:10 Lession7_Pandas_Sortinh.ipynb
# -rw-r--r--@ 1 sam  staff    81K Apr  5 19:26 Lession8_Explore_Analyze_Data.ipynb
# -rw-r--r--@ 1 sam  staff   122K Apr 10 22:49 Lession10_Pandas_Dates_Times.ipynb
# -rw-r--r--@ 1 sam  staff   194K Apr 11 11:05 Lession11_Pandas_File_Handling.ipynb
# -rw-r--r--@ 1 sam  staff   192K Apr 11 16:32 Lession9_Cleaning_Data.ipynb
# -rw-r--r--@ 1 sam  staff   433K Apr 11 17:17 Lession1_Pandas.ipynb
# -rw-r--r--@ 1 sam  staff   190K Apr 11 17:57 Lession2_Pandas.ipynb

# %%
inpFilePath ='/Users/sam/git/Pandas_Data/Input/Data_2019/'
df = pd.read_csv(inpFilePath+'survey_results_public.csv')
schema_df = pd.read_csv(inpFilePath+'survey_results_schema.csv')
pd.set_option('display.max_columns', 85) #to display all columns in the dataframe
pd.set_option('display.max_rows', 85)   #to see all rows in the dataframe of schema
pd.set_option('max_colwidth', 100) #to see the 1000 chars column width of the dataframe of schema

#Just for Understanding: 
#In dictioneries a single key has single value
#but in DataFrame a single key can have multiple values 
#i.e. values are stored in list


'''

#Standard Definition of Dictionary
Sample_Dict ={
    "First": "Sam",
    "Last": "Thakur",
    "Age": "34"
}


#Making All of Values in Dictionary as List
Sample_Dict ={
    "First": ["Sam"],
    "Last": ["Thakur"],
    "Age": ["34"]
}

#Making All of Values in Dictionary as List of Multiple Values
Sample_Dict ={
    "First": ["Sam","Archna","Anaysha"],
    "Last": ["Thakur","Puri","Thakur],
    "Age": ["34","33","1"]
}



'''
# Out:
# '\n\n#Standard Definition of Dictionary\nSample_Dict ={\n    "First": "Sam",\n    "Last": "Thakur",\n    "Age": "34"\n}\n\n\n#Making All of Values in Dictionary as List\nSample_Dict ={\n    "First": ["Sam"],\n    "Last": ["Thakur"],\n    "Age": ["34"]\n}\n\n#Making All of Values in Dictionary as List of Multiple Values\nSample_Dict ={\n    "First": ["Sam","Archna","Anaysha"],\n    "Last": ["Thakur","Puri","Thakur],\n    "Age": ["34","33","1"]\n}\n\n\n\n'

# %%
df.head()
# Out:
#    Respondent  \
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#
#                                                                       MainBranch  \
# 0                                         I am a student who is learning to code
# 1                                         I am a student who is learning to code
# 2  I am not primarily a developer, but I write code sometimes as part of my work
# 3                                                 I am a developer by profession
# 4                                                 I am a developer by profession
#
#   Hobbyist                 OpenSourcer  \
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
#
#                                                                         OpenSource  \
# ...

# %%
schema_df.head()
# Out:
#         Column  \
# 0   Respondent
# 1   MainBranch
# 2     Hobbyist
# 3  OpenSourcer
# 4   OpenSource
#
#                                                                                           QuestionText
# 0                               Randomized respondent ID number (not in order of survey response time)
# 1  Which of the following options best describes you today? Here, by "developer" we mean "someone w...
# 2                                                                              Do you code as a hobby?
# 3                                                          How often do you contribute to open source?
# 4                                     How do you feel about the quality of open source software (OSS)?

# %%
df['MainBranch']
# Out:
# 0                                               I am a student who is learning to code
# 1                                               I am a student who is learning to code
# 2        I am not primarily a developer, but I write code sometimes as part of my work
# 3                                                       I am a developer by profession
# 4                                                       I am a developer by profession
#                                              ...
# 88878                                                                              NaN
# 88879                                                                              NaN
# 88880                                                                              NaN
# 88881                                                                              NaN
# 88882                                                                              NaN
# Name: MainBranch, Length: 88883, dtype: object

# %%
type(df['MainBranch'])
#pandas.core.series.Series
# Series object is a row of single column of data in a dataframe
# Data Frame is container for multiple series objetcs
# Out:
# pandas.core.series.Series

# %%
df.MainBranch
#same as df['MainBranch']
#but better to use df['MainBranch'] becuase one of the name of columns of df can be same as methods/attributes of df 
# e.g. sometimes df.count will access count method in df rather than column
# Out:
# 0                                               I am a student who is learning to code
# 1                                               I am a student who is learning to code
# 2        I am not primarily a developer, but I write code sometimes as part of my work
# 3                                                       I am a developer by profession
# 4                                                       I am a developer by profession
#                                              ...
# 88878                                                                              NaN
# 88879                                                                              NaN
# 88880                                                                              NaN
# 88881                                                                              NaN
# 88882                                                                              NaN
# Name: MainBranch, Length: 88883, dtype: object

# %%
df[['MainBranch','Hobbyist']] 
#List of Columns to access multiple columns of dataframe
# if only given single brancket python will think name of column is " MainBranch','Hobbyist " 
#Multiple columns giving another sub dataframe not series now
# Out:
#                                                                           MainBranch  \
# 0                                             I am a student who is learning to code
# 1                                             I am a student who is learning to code
# 2      I am not primarily a developer, but I write code sometimes as part of my work
# 3                                                     I am a developer by profession
# 4                                                     I am a developer by profession
# ...                                                                              ...
# 88878                                                                            NaN
# 88879                                                                            NaN
# 88880                                                                            NaN
# 88881                                                                            NaN
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc

# %%
df.iloc[0]
#iloc is used to access row by integer location
#values of first row of data frame
#index here is column name
# Out:
# Respondent                                                                                                                  1
# MainBranch                                                                             I am a student who is learning to code
# Hobbyist                                                                                                                  Yes
# OpenSourcer                                                                                                             Never
# OpenSource                                                    The quality of OSS and closed source software is about the same
# Employment                                                                             Not employed, and not looking for work
# Country                                                                                                        United Kingdom
# ...

# %%
df.iloc[0:3]
#First 3 rows of data frame
#Here in iLoc the end index is exclusive
#But in loc the "end Label" is inclusive because it is label base indexing not location based indexing
# Out:
#    Respondent  \
# 0           1
# 1           2
# 2           3
#
#                                                                       MainBranch  \
# 0                                         I am a student who is learning to code
# 1                                         I am a student who is learning to code
# 2  I am not primarily a developer, but I write code sometimes as part of my work
#
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                                         OpenSource  \
# 0  The quality of OSS and closed source software is about the same
# 1  The quality of OSS and closed source software is about the same
# 2  The quality of OSS and closed source software is about the same
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# ...

# %%
df.iloc[[0,1],[2,3]]
#1st argument is list of row index and 2nd argument is list of column index
# Out:
#   Hobbyist              OpenSourcer
# 0      Yes                    Never
# 1       No  Less than once per year

# %%
df.head()
# Out:
#    Respondent  \
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#
#                                                                       MainBranch  \
# 0                                         I am a student who is learning to code
# 1                                         I am a student who is learning to code
# 2  I am not primarily a developer, but I write code sometimes as part of my work
# 3                                                 I am a developer by profession
# 4                                                 I am a developer by profession
#
#   Hobbyist                 OpenSourcer  \
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
#
#                                                                         OpenSource  \
# ...

# %%
df.loc[0:2,'MainBranch':'Hobbyist']
#slicing is inclusive in loc because it is label based indexing
# searching by label of row and column
#rows do not have lable so default lable is 0,1,2,..
#column do have lable so we can use column name to access the data
# Out:
#                                                                       MainBranch  \
# 0                                         I am a student who is learning to code
# 1                                         I am a student who is learning to code
# 2  I am not primarily a developer, but I write code sometimes as part of my work
#
#   Hobbyist
# 0      Yes
# 1       No
# 2      Yes

# %%
df.shape
# Out:
# (88883, 85)

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
#Gives count of each unique value in the column
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                                                                                  1
# MainBranch                                                                             I am a student who is learning to code
# Hobbyist                                                                                                                  Yes
# OpenSourcer                                                                                                             Never
# OpenSource                                                    The quality of OSS and closed source software is about the same
# Employment                                                                             Not employed, and not looking for work
# Country                                                                                                        United Kingdom
# ...

# %%
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[0,1,2],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:5,'Hobbyist':'Employment']
#last value i.e. 5 above is inclusive
#employement also inclusive
# Out:
#   Hobbyist                 OpenSourcer  \
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
# 5      Yes                       Never
#
#                                                                         OpenSource  \
# 0                  The quality of OSS and closed source software is about the same
# 1                  The quality of OSS and closed source software is about the same
# 2                  The quality of OSS and closed source software is about the same
# 3                  The quality of OSS and closed source software is about the same
# 4  OSS is, on average, of HIGHER quality than proprietary / closed source software
# 5                  The quality of OSS and closed source software is about the same
#
#                                Employment
# 0  Not employed, and not looking for work
# ...
