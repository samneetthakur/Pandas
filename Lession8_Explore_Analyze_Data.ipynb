# %%
#Different methods to explore/analyze the data in a dataframe

#df['Column_Name'].count() # number of non-null values in the column
#df['Column_name'].value_counts() # number of occurences of each value in the column, basically histogram bins
#df['Column_name'].mean() #mean of the column, will ignore null values
#df['Column_name'].median() #median of the column, will ignore null values
#df['Column_name'].min() #minimum value in the column, will ignore null values
#df['Column_name'].max() #maximum value in the column, will ignore null values
#df.median() #median of all the valid columns in the dataframe, will ignore null values : valid means float or int data type
#df.describe() #summary of all the valid columns in the dataframe, will ignore null values : valid means float or int data typeS
#df['Column_name'].value_counts(normalize=True) #normalzied number of occurences of each value in the column, will ignore null values

# grp = df.groupby(['Column_name']) 
#group the dataframe by the values in the Country column, 
#this will create a group for each unique value in the Country column and will allow us to perform operations on each group separately
#A groupby operation involves some combination of splitting the object, 
#applying a function, and combining the results. 
# This can be used to group large amounts of data and compute operations on these groups.
#grp.get_group('Country_Name').describe() #will describe the group of rows where the value in the Country column is Country_NameS





import pandas as pd
inpFilePath ='/Users/sam/git/Pandas_Data/Input/Data_2019/'
df = pd.read_csv(inpFilePath + 'survey_results_public.csv')
schema_df = pd.read_csv(inpFilePath + 'survey_results_schema.csv')
pd.set_option('display.max_columns', 85) #to display all columns in the dataframe
pd.set_option('display.max_rows', 85)   #to see all rows in the dataframe of schema
pd.set_option('display.width', 100)    #to set the width of the display to 1000 characters

people = {
    "first": ["Corey", "Jane", "John","Adam"],
    "last": ["Schafer", "Doe", "Doe","Doe"],
    "email": ["Corey.Schafer@gmail.com", "Jane.Doe@gmail.com", "John.Smith@gmail.com","Adam.Doe@gmail.com"]
}
df1 = pd.DataFrame(people)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer                                         OpenSource  \
# 0                       Never  The quality of OSS and closed source software ...
# 1     Less than once per year  The quality of OSS and closed source software ...
# 2                       Never  The quality of OSS and closed source software ...
# 3                       Never  The quality of OSS and closed source software ...
# 4  Once a month or more often  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['ConvertedComp'].count() # number of non-null values in the column
# Out:
# 55823

# %%
df['ConvertedComp'].value_counts() # number of occurences of each value in the column, basically histogram bins
# Out:
# 2000000.0    709
# 1000000.0    558
# 120000.0     502
# 100000.0     480
# 150000.0     434
#             ...
# 52826.0        1
# 72888.0        1
# 7548.0         1
# 20436.0        1
# 44947.0        1
# Name: ConvertedComp, Length: 9162, dtype: int64

# %%
df['ConvertedComp'].head(15)
# Out:
# 0          NaN
# 1          NaN
# 2       8820.0
# 3      61000.0
# 4          NaN
# 5     366420.0
# 6          NaN
# 7          NaN
# 8      95179.0
# 9      13293.0
# 10         NaN
# 11         NaN
# 12     90000.0
# 13     57060.0
# 14         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].mean() #mean of the column, will ignore null values
# Out:
# 127110.73842323056

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# Respondent       44442.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df['Column']
# Out:
# 0                 Respondent
# 1                 MainBranch
# 2                   Hobbyist
# 3                OpenSourcer
# 4                 OpenSource
# 5                 Employment
# 6                    Country
# 7                    Student
# 8                    EdLevel
# 9             UndergradMajor
# 10                  EduOther
# 11                   OrgSize
# 12                   DevType
# 13                 YearsCode
# 14                Age1stCode
# 15              YearsCodePro
# 16                 CareerSat
# 17                    JobSat
# 18                  MgrIdiot
# 19                  MgrMoney
# 20                   MgrWant
# 21                   JobSeek
# 22              LastHireDate
# 23                   LastInt
# 24                  FizzBuzz
# 25                JobFactors
# 26              ResumeUpdate
# 27            CurrencySymbol
# 28              CurrencyDesc
# 29                 CompTotal
# 30                  CompFreq
# 31             ConvertedComp
# ...

# %%
schema_df[schema_df['Column'] =='SocialMedia'] 
#what is the value of the row where the column name is SocialMedia in the schema dataframe
# Out:
#          Column                                 QuestionText
# 61  SocialMedia  What social media site do you use the most?

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Sao Tome and Principe                   1
# Dominica                                1
# Papua New Guinea                        1
# Brunei Darussalam                       1
# Saint Vincent and the Grenadines        1
# Name: Country, Length: 179, dtype: int64

# %%
df.groupby(['Country'])
#group the dataframe by the values in the Country column, 
# this will create a group for each unique value in the Country column 
# and will allow us to perform operations on each group separately

# %%
Countrygrp = df.groupby(['Country'])

# %%
Countrygrp.describe()
#Information about each unique value in the Country column,
#Is described here for all valid columns in the dataframe, will ignore null values : valid columns means  those columns with float or int data type
# Out:
#                                      Respondent                                                 \
#                                           count          mean           std      min       25%
# Country
# Afghanistan                                44.0  47441.431818  26547.217894    722.0  28943.25
# Albania                                    86.0  41695.546512  24199.484198   1954.0  19187.25
# Algeria                                   134.0  43010.126866  25308.029814   1102.0  22301.75
# Andorra                                     7.0  50079.857143  33627.941940   1547.0  28684.50
# Angola                                      5.0  50569.400000  28639.499460   8172.0  46837.00
# ...                                         ...           ...           ...      ...       ...
# Venezuela, Bolivarian Republic of...       88.0  43461.170455  25866.546647   1438.0  19100.75
# Viet Nam                                  231.0  43895.337662  24367.137680    161.0  24468.00
# ...

# %%
Countrygrp.get_group('India').describe()
# Out:
#          Respondent     CompTotal  ConvertedComp  WorkWeekHrs   CodeRevHrs          Age
# count   9061.000000  4.017000e+03   3.999000e+03  5571.000000  5058.000000  7307.000000
# mean   44477.174043  5.061513e+07   2.805766e+04    42.203159     7.297837    25.927439
# std    25514.630987  3.155567e+09   8.563000e+04    66.273189     8.185413     5.443127
# min        8.000000  0.000000e+00   0.000000e+00     2.000000     0.000000     1.000000
# 25%    22303.000000  4.000000e+04   5.040000e+03    40.000000     3.000000    22.000000
# 50%    44494.000000  4.050000e+05   1.008000e+04    42.000000     5.000000    25.000000
# 75%    66294.000000  1.100000e+06   2.098900e+04    48.000000    10.000000    28.000000
# max    88872.000000  2.000000e+11   2.000000e+06  4850.000000    99.000000    98.000000

# %%
#another way to do is using filt and loc based selection
filt1 = df['Country'] == 'India'
df.loc[filt1].describe()
# Out:
#          Respondent     CompTotal  ConvertedComp  WorkWeekHrs   CodeRevHrs          Age
# count   9061.000000  4.017000e+03   3.999000e+03  5571.000000  5058.000000  7307.000000
# mean   44477.174043  5.061513e+07   2.805766e+04    42.203159     7.297837    25.927439
# std    25514.630987  3.155567e+09   8.563000e+04    66.273189     8.185413     5.443127
# min        8.000000  0.000000e+00   0.000000e+00     2.000000     0.000000     1.000000
# 25%    22303.000000  4.000000e+04   5.040000e+03    40.000000     3.000000    22.000000
# 50%    44494.000000  4.050000e+05   1.008000e+04    42.000000     5.000000    25.000000
# 75%    66294.000000  1.100000e+06   2.098900e+04    48.000000    10.000000    28.000000
# max    88872.000000  2.000000e+11   2.000000e+06  4850.000000    99.000000    98.000000

# %%
Countrygrp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
Countrygrp['SocialMedia'].value_counts().loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               442
# YouTube                     302
# I don't use social media    155
# Reddit                      140
# Twitter                     130
# Instagram                    94
# WhatsApp                     90
# Facebook                     67
# LinkedIn                     35
# Snapchat                      1
# Name: SocialMedia, dtype: int64

# %%
Countrygrp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
Countrygrp['ConvertedComp'].agg(['median','mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
Countrygrp['ConvertedComp'].agg(['median','mean']).loc['United States']
# Out:
# median    110000.000000
# mean      249546.254589
# Name: United States, dtype: float64

# %%
filt1 = df['Country'] == 'India'
df.loc[filt1]['LanguageWorkedWith']
# Out:
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9                            C#;Go;JavaScript;Python;R;SQL
# 14       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 49       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 64                         Assembly;C;C++;C#;HTML/CSS;Java
#                                ...
# 88808                                            Other(s):
# 88825                 Bash/Shell/PowerShell;Python;SQL;VBA
# 88852    Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 88853     HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 88864        Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
filt1 = df['Country'] == 'India'
df.loc[filt1]['LanguageWorkedWith'].str.contains('Python')
# Out:
# 7         True
# 9         True
# 14       False
# 49        True
# 64       False
#          ...
# 88808    False
# 88825     True
# 88852    False
# 88853     True
# 88864    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
filt1 = df['Country'] == 'India'
df.loc[filt1]['LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    5739
# True     3105
# Name: LanguageWorkedWith, dtype: int64

# %%
'''
Countrygrp['LanguageWorkedWith'].str.contains('Python').sum()S
---------------------------------------------------------------------------
AttributeError                            Traceback (most recent call last)
<ipython-input-62-b0e25984d7ed> in <module>
----> 1 Countrygrp['LanguageWorkedWith'].str.contains('Python').sum()

~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
    701             return self[attr]
    702 
--> 703         raise AttributeError(
    704             f"'{type(self).__name__}' object has no attribute '{attr}'"
    705         )

AttributeError: 'SeriesGroupBy' object has no attribute 'str'

'''

# %%
Countrygrp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').value_counts(normalize=True))
# Out:
# Country
# Afghanistan  False    0.794872
#              True     0.205128
# Albania      False    0.722892
#              True     0.277108
# Algeria      False    0.682540
#                         ...
# Yemen        True     0.176471
# Zambia       False    0.666667
#              True     0.333333
# Zimbabwe     False    0.641026
#              True     0.358974
# Name: LanguageWorkedWith, Length: 335, dtype: float64
