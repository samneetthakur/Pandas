# %%
import pandas as pd
df = pd.read_csv('./Data_2019/survey_results_public.csv')
schema_df = pd.read_csv('./Data_2019/survey_results_schema.csv')
pd.set_option('display.max_columns', 85) #to display all columns in the dataframe
pd.set_option('display.max_rows', 85)   #to see all rows in the dataframe of schema

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['SocialMedia'] == 'Twitter'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: SocialMedia, Length: 88883, dtype: bool

# %%
filt1 = (df['SocialMedia'] == 'Twitter')

# %%
df[filt1]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 8               9          I am a developer by profession      Yes
# 12             13          I am a developer by profession      Yes
# 43             44          I am a developer by profession      Yes
# 59             60          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88836       81934                                     NaN      Yes
# 88850       83786                                     NaN       No
# 88852       83862                                     NaN      Yes
# 88857       85396                                     NaN       No
# 88875       88182                                     NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %%
df[df['SocialMedia'] == 'Twitter']
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 8               9          I am a developer by profession      Yes
# 12             13          I am a developer by profession      Yes
# 43             44          I am a developer by profession      Yes
# 59             60          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88836       81934                                     NaN      Yes
# 88850       83786                                     NaN       No
# 88852       83862                                     NaN      Yes
# 88857       85396                                     NaN       No
# 88875       88182                                     NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %%
df[filt1].iloc[1]
# Out:
# Respondent                                                                9
# MainBranch                                   I am a developer by profession
# Hobbyist                                                                Yes
# OpenSourcer                                      Once a month or more often
# OpenSource                The quality of OSS and closed source software ...
# Employment                                               Employed full-time
# Country                                                         New Zealand
# Student                                                                  No
# EdLevel                   Some college/university study without earning ...
# UndergradMajor            Computer science, computer engineering, or sof...
# EduOther                  Taken an online course in programming or softw...
# OrgSize                                                  10 to 19 employees
# ...

# %%
df.loc[filt1] # this is same as df[filt1]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 8               9          I am a developer by profession      Yes
# 12             13          I am a developer by profession      Yes
# 43             44          I am a developer by profession      Yes
# 59             60          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88836       81934                                     NaN      Yes
# 88850       83786                                     NaN       No
# 88852       83862                                     NaN      Yes
# 88857       85396                                     NaN       No
# 88875       88182                                     NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %%
df.loc[filt1,'Employment'] #to get the employment column for those who use twitter
# Out:
# 0                   Not employed, and not looking for work
# 8                                       Employed full-time
# 12                                      Employed full-time
# 43                                      Employed full-time
# 59                                      Employed full-time
#                                ...
# 88836               Not employed, and not looking for work
# 88850                                   Employed full-time
# 88852                                   Employed full-time
# 88857    Independent contractor, freelancer, or self-em...
# 88875                                   Employed part-time
# Name: Employment, Length: 11398, dtype: object

# %%
filt2 =(df['SocialMedia'] == 'Twitter') & (df['Employment'] == 'Not employed, but looking for work')

# %%
df.loc[filt2]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 226           228  I am not primarily a developer, but I write co...       No
# 270           272             I am a student who is learning to code      Yes
# 282           284             I am a student who is learning to code      Yes
# 515           517  I am not primarily a developer, but I write co...       No
# 779           782             I am a student who is learning to code      Yes
# ...           ...                                                ...      ...
# 86676       87216             I am a student who is learning to code      Yes
# 87152       87694             I am a student who is learning to code      Yes
# 87177       87719                     I am a developer by profession      Yes
# 88140       88690                     I am a developer by profession      Yes
# 88363        7759                                                NaN      Yes
#
# ...

# %%
df.loc[filt2,'Country']
# Out:
# 226             France
# 270             Serbia
# 282             Canada
# 515      United States
# 779              Kenya
#              ...
# 86676            Spain
# 87152        Australia
# 87177    United States
# 88140    United States
# 88363          Ecuador
# Name: Country, Length: 452, dtype: object

# %%
high_salary = df['ConvertedComp'] > 70000
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...               ...                                                ...
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt3 = df['Country'].isin(countries)
df.loc[filt3,'Country'].value_counts()
# Out:
# United States     20949
# India              9061
# Germany            5866
# United Kingdom     5737
# Canada             3395
# Name: Country, dtype: int64

# %%
filt4 = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt4]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 1               2  I am a student who is learning to code       No
# 3               4          I am a developer by profession       No
# 4               5          I am a developer by profession      Yes
# 7               8             I code primarily as a hobby      Yes
# ...           ...                                     ...      ...
# 88854       84539                                     NaN      Yes
# 88860       85738                                     NaN      Yes
# 88865       86566                                     NaN      Yes
# 88872       87739                                     NaN      Yes
# 88876       88212                                     NaN       No
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...
